# %% [markdown]
# # Testing Project Data Uploads

# %%
#Import Statements
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Project Data Stripped.xlsx')

# %%
df.head()
# Out:
#    M/F   Age  UnitNumber  ReportYear  ReportMonth ReportDateFull Gender  \
# 0    M  37.0         534        2013            1     2013-01-01      M
# 1  NaN   NaN         564        2013            1     2013-01-02      M
# 2  NaN  78.0         534        2013            1     2013-01-03      F
# 3    F   NaN         534        2013            1     2013-01-05      U
# 4    F  43.0         534        2013            1     2013-01-11      F
#
#                    DOB                 CodeSection Badge Supervisor  \
# 0  1975-07-30 00:00:00             T14/CCR 4326(a)  1433       1245
# 1              Unknown            Public Complaint  1464       1245
# 2  1934-06-03 00:00:00              Medical - Fall  1464       1245
# 3              Unknown  Traffic Collision (Injury)  1245       1075
# 4  1969-11-10 00:00:00              Felony Warrant  1564       1245
#
#           Medical PC/CVC                       OTHER
# 0             NaN    NaN             T14/CCR 4326(a)
# 1             NaN    NaN            Public Complaint
# 2  Medical - Fall    NaN                         NaN
# 3             NaN    NaN  Traffic Collision (Injury)
# 4             NaN    NaN              Felony Warrant

# %%
np.shape(df)
# Out:
# (1913, 10)

# %%
X = df.drop(["M/F", "ReportDateFull", "DOB", "CodeSection", "Gender", "Supervisor"], axis=1)

# %%
X.head()
# Out:
#     Age  UnitNumber  ReportYear  ReportMonth Badge         Medical PC/CVC  \
# 0  37.0         534        2013            1  1433             NaN    NaN
# 1   NaN         564        2013            1  1464             NaN    NaN
# 2  78.0         534        2013            1  1464  Medical - Fall    NaN
# 3   NaN         534        2013            1  1245             NaN    NaN
# 4  43.0         534        2013            1  1564             NaN    NaN
#
#                         OTHER
# 0             T14/CCR 4326(a)
# 1            Public Complaint
# 2                         NaN
# 3  Traffic Collision (Injury)
# 4              Felony Warrant

# %%
#Relabel Gender
#0 - Male
#1 - Female
#-1 - Unknown

#Relatable Misdimeanor/Felony
#0 - Misdimeanor
#1 - Felony
#-1 - Neither

s,f = np.shape(df)
for i in range(s):
    if df.loc[i, 'Gender'] == 'M':
        df.loc[i, 'Gender'] = 0
    elif df.loc[i, 'Gender'] == 'F':
        df.loc[i, 'Gender'] = 1
    else:
        df.loc[i, 'Gender'] = -1

for i in range(s):
    if df.loc[i, 'M/F'] == 'M':
        df.loc[i, 'M/F'] = 0
    elif df.loc[i, 'M/F'] == 'F':
        df.loc[i, 'M/F'] = 1
    else:
        df.loc[i, 'M/F'] = -1        
df.head()
# Out:
#    M/F   Age  UnitNumber  ReportYear  ReportMonth ReportDateFull  Gender  \
# 0    0  37.0         534        2013            1     2013-01-01       0
# 1   -1   NaN         564        2013            1     2013-01-02       0
# 2   -1  78.0         534        2013            1     2013-01-03       1
# 3    1   NaN         534        2013            1     2013-01-05      -1
# 4    1  43.0         534        2013            1     2013-01-11       1
#
#                    DOB                 CodeSection Badge Supervisor  \
# 0  1975-07-30 00:00:00             T14/CCR 4326(a)  1433       1245
# 1              Unknown            Public Complaint  1464       1245
# 2  1934-06-03 00:00:00              Medical - Fall  1464       1245
# 3              Unknown  Traffic Collision (Injury)  1245       1075
# 4  1969-11-10 00:00:00              Felony Warrant  1564       1245
#
#           Medical PC/CVC                       OTHER
# 0             NaN    NaN             T14/CCR 4326(a)
# 1             NaN    NaN            Public Complaint
# 2  Medical - Fall    NaN                         NaN
# 3             NaN    NaN  Traffic Collision (Injury)
# 4             NaN    NaN              Felony Warrant

# %%
dfNew = df[df.Gender != -1]
dfNew.head()
# Out:
#    M/F  UnitNumber  ReportYear  ReportMonth ReportDateFull Gender  \
# 0    F         564        2015            1     2015-01-01      0
# 1    M         564        2015            1     2015-01-01      0
# 2  NaN         534        2015            1     2015-01-03      0
# 3  NaN         534        2015            1     2015-01-05      0
# 4  NaN         564        2015            1     2015-01-16      1
#
#                    DOB                            CodeSection Badge  \
# 0  1970-12-07 00:00:00  CVC 21200.5 - DUI Bike CVC 23152(a(b)  1464
# 1  1987-09-19 00:00:00                       PC 647(f) PC 415  1606
# 2                  NaN      Traffic Collision Property Damage  1509
# 3  1948-05-19 00:00:00          Medical - Dislocated Shoulder  1464
# 4  1993-05-21 00:00:00                           PC 166(a)(4)  1606
#
#    Supervisor
# 0      1075.0
# 1       489.0
# 2      1409.0
# 3      1409.0
# 4      1409.0

# %%
import numpy as np
import sklearn.model_selection as ms

#Returns scores from KFold cross validation of n folds
#X_train - training data frame
#y_train - traininng labels data frame
#clf - Classifier
#n - Number of folds
def cross_val_scores(X_train, y_train, clf=None, n=5):
    scores = []
    kf = ms.KFold(n, shuffle=True)
    for train, validate in kf.split(X_train):
        clf.fit(X_train[train], y_train[train])
        scores.append(clf.score(X_train[validate], y_train[validate]))
    return scores

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg_scores = cross_val_scores(X_train,y_train, logreg)
print(logreg_scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-f2fc0900c74f> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 logreg = LogisticRegression()
# ----> 3 logreg_scores = cross_val_scores(X_train,y_train, logreg)
#       4 print(logreg_scores)
#
# <ipython-input-119-d2fc09438500> in cross_val_scores(X_train, y_train, clf, n)
#      11     kf = ms.KFold(n, shuffle=True)
#      12     for train, validate in kf.split(X_train):
# ---> 13         clf.fit(X_train[train], y_train[train])
#      14         scores.append(clf.score(X_train[validate], y_train[validate]))
#      15     return scores
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1214
#    1215         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
# -> 1216                          order="C")
#    1217         check_classification_targets(y)
#    1218         self.classes_ = np.unique(y)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'LG II Butler'
